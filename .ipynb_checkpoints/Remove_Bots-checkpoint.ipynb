# %%
import pandas as pd

# %%
df = pd.read_parquet('datasets/btc_tweets_train.parquet.gzip')

# %%
df = df.reset_index()

# %%
df.head()
# Out:
#               tweet ID                                           hashtags  \
# 0  1641579121972236290  [Bitcoin, Bitcoin, BTC, Bitcoin, BTC, SHIB, HO...
# 1  1641579176171016194                 [Bitcoin, bitcoinordinals, crypto]
# 2  1641579486071390208  [BTC, SHIB, HOGE, SAITAMA, BNB, DOGE, ETH, Bab...
# 3  1641579537103302656                                              [BTC]
# 4  1641579588399804418                                          [Bitcoin]
#
#                                              content      username  \
# 0  $Bitcoin TO $100,000 SOONER THAN YOU THINK‼️💯🙏...   BezosCrypto
# 1  Alright I have my rares. Who else is grabbing ...   spartantc81
# 2  Bitcoin (BTC) Targets Over $100,000 as This Im...   BezosCrypto
# 3  📢 Xverse Web-based pool is live:\n\n•Update @x...  godfred_xcuz
# 4  Yesterday, a Bitcoin projection was displayed ...   goddess81oo
#
#   user_displayname  sentiment
# 0       SHIB Bezos       True
# 1        SpartanTC       True
# 2       SHIB Bezos       True
# 3    Algorithm.btc       True
# 4     she is lucky       True

# %%
df.shape
# Out:
# (1500, 6)

# %% [markdown]
# ### 1. Username Analysis

# %%
# Check for usernames with a high number of digits
df['num_digits_in_username'] = df['username'].apply(lambda x: sum(c.isdigit() for c in x))
high_digit_usernames = df[df['num_digits_in_username'] > 5]  # Arbitrary threshold, can be adjusted

# Check for repetitive characters in usernames
df['repetitive_username'] = df['username'].apply(lambda x: any([x.count(char * 3) > 0 for char in set(x)]))
repetitive_usernames = df[df['repetitive_username']]

# Combine both checks
suspicious_usernames = df[(df['num_digits_in_username'] > 5) | (df['repetitive_username'])]

print(suspicious_usernames[['username', 'user_displayname', 'content']])
# Out:
#              username                user_displayname  \
# 170    AboMost0568888         TIGER💥 momen RRR ✍✍ 💥💎💎
# 174   meshari79441510                  Shibarium News
# 197   ryansmi65393560                    k:DeFiRy⛓️🕸️
# 435          Bennnoss                         Ben | 🪢
# 451   nergizy32132110                       BABY LUNC
# 457          m30_2022                           M_30✨
# 478   Abhinav18755615                         Abhinav
# 508    AboMost0568888         TIGER💥 momen RRR ✍✍ 💥💎💎
# 519          vasssek_                       vasek.eth
# 587         baatar666                          baatar
# 631   michael000Best1       Mike Trollcoin Ambassador
# 648     SaqlainAli888                     Saqlain Ali
# 667         888Velvet                       MAXi // 📈
# 670       ama_serwaaa                      Ama Judith
# 706       MoCrypto777                     MoCrypto777
# 726   CryptoAnu530154                 🪬 🌐𝕮𝖗𝖞𝖕𝖙𝖔.𝕬𝖓𝖚🌐🪬
# 751    AboMost0568888         TIGER💥 momen RRR ✍✍ 💥💎💎
# 757    AboMost0568888         TIGER💥 momen RRR ✍✍ 💥💎💎
# 796          Bennnoss                         Ben | 🪢
# 892        IIICapital                Joe Burnett (🔑)³
# 969   CryptoA40672341  Crypto Analyst(No paid groups)
# 1060    SaqlainAli888                     Saqlain Ali
# 1088      ROWEBOT3339                         ROWEBOT
# 1174   WoodsWoods1111                           Woods
# 1209  CryptoA40672341  Crypto Analyst(No paid groups)
# 1227        Mrroccooo                           rocco
# 1259  CryptoAnu530154                 🪬 🌐𝕮𝖗𝖞𝖕𝖙𝖔.𝕬𝖓𝖚🌐🪬
# 1265  CryptoA40672341  Crypto Analyst(No paid groups)
# 1273   MagicSpeed8888             Magic Speed 🇨🇳 🇭🇰 🐂
# 1380  CryptoA40672341  Crypto Analyst(No paid groups)
# 1400    SaqlainAli888                     Saqlain Ali
# 1482       IIICapital                Joe Burnett (🔑)³
# 1492   AboMost0568888         TIGER💥 momen RRR ✍✍ 💥💎💎
#
#                                                 content
# 170   $Mswap\n\nA large green candle is prepared on ...
# 174   #BONE Stats:\n\n🍖Price:$1.06🚀\n🍖Market 🧢:$243....
# 197   @up_holdem $NEXA the bull 🔥💯💪🚀 #NEXA #BTC #Kas...
# 435   Do you believe $CHNG will remain at $0.10 with...
# 451   #LUNC to 1 USD: Terra Classic L1 Team Releases...
# 457   BTC 📉🙂\n\n✨ misery loves company ✨\n\n ♥️ No R...
# 478   #Pulsechain -41,810\n\n#Pulsex -136174\n\n#HEX...
# 508   Very cool $naos on the way to achieve the big ...
# 519   Fantastic 3D artist with good opinion on $RINI...
# 587   What do you think? The next possible thoughts ...
# 631   Let build the number 1 #meme community on #cro...
# 648   Today #LUNC is trading at 0.000122 price &amp;...
# 667   #BULLISH Q1  = 👍\n\n👉 #BULLISH on Q2 = 👇\n\n#B...
# 670   #AviveWorld is the world's best option for you...
# 706   📺New Video: https://t.co/axgeF3lz3b\n\nThis ha...
# 726   #Bitcoin Volatility Likely as Options Worth $4...
# 751   $Naos\nKill the first zero is coming\n\n5×  so...
# 757   Adding a new #hiundead bag on kucoin now\n\nBi...
# 796   Something really special is happening right no...
# 892   This is the first #Bitcoin bear market where a...
# 969   Warning 🚨:\nBe careful buying /longing #btc no...
# 1060  57 #LUNC Warriors NFTs got mi ted so far &amp;...
# 1088  #Bitcoin = Savings Account\n#Litecoin = Checki...
# 1174  Where you can buy #Tel #telcoin #btc #ada #sol...
# 1209  They bought and longed the resistance . Dump i...
# 1227  Besides #Bitcoin and #ethereum have y’all seen...
# 1259  Long, short, buy, and sell #Lunc, #Bitcoin, an...
# 1265  #btc 1 hr looks scary .\nDangerously overbough...
# 1273  @NakamotoGames WTF! As mentioned earlier $NAKA...
# 1380  120 #btc selling whales on Coinbase pro at bel...
# 1400  Total of 51b #LUNCBURN done &amp; 34.4b got bu...
# 1482  Altcoiners should be more humble.\n\nJust admi...
# 1492  #Hiundead\nThe patient will win\n\nBig  pump c...

# %% [markdown]
# ### 2. Hashtag Analysis (This is still not generating satisfactory results)

# %%
# Count the number of hashtags in each tweet
df['num_hashtags'] = df['content'].apply(lambda x: len(x.split()) if isinstance(x, str) else 0)

# Flag tweets with more than a typical number of hashtags (e.g., >3)
suspicious_hashtags = df[df['num_hashtags'] > 3]

print(suspicious_hashtags[['username', 'num_hashtags', 'hashtags', 'content']])

# %% [markdown]
# ### 3. Content Similarity Analysis

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Vectorize the tweet content
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(df['content'])

# Calculate cosine similarity matrix
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# Set a threshold for similarity (e.g., >0.8) to find suspiciously similar tweets
suspicious_pairs = []
for i in range(len(cosine_sim)):
    for j in range(i+1, len(cosine_sim)):
        if cosine_sim[i, j] > 0.80:
            suspicious_pairs.append((i, j))

# Get the suspicious tweets based on content similarity
for i, j in suspicious_pairs:
    print(f"Tweet {i}: {df.iloc[i]['content']}")
    print(f"Tweet {j}: {df.iloc[j]['content']}")
    print("-------")
# Out:
# Tweet 9: IBIS SACRED, new solana project. metaverse community
# LINK : https://t.co/LKBUnJkVIW
#
# Be part of Ibis Sacred Community
#
# @hey_wallet
#   send 13333 $FRONK to the first 500 retweets and follows
#
# #Solana #bitcoin #FRONK #BONK #CRYPTO #ETH #BSC #BNB #metaverse https://t.co/MOC2QOhfWU
# Tweet 110: IBIS SACRED, new solana project. metaverse community
# LINK : https://t.co/V0Otvt4e2D
#
# Be part of Ibis Sacred Community
#
# @hey_wallet
#   send 13333 $FRONK to the first 500 retweets and follows
#
# #Solana #bitcoin #FRONK #BONK #CRYPTO #ETH #BSC #BNB #metaverse https://t.co/uMTEryVKrN
# -------
# Tweet 13: Free #NFT Giveaway🎁
#
# 🚨Drop your $ETH address wallet.
#
# 🚨Follow me and Retweet.
# #nfts #nft #nftart #nftcommunity #nftcollector #nftartist #digitalart #crypto #cryptoart #art #ethereum #opensea #nftcollectors #blockchain #nftdrop #nftcollectibles #cryptocurrency #Bitcoin https://t.co/ZCFUoUQH1d
# Tweet 117: Free #NFT Giveaway🎁
#
# 🚨Drop your $ETH address wallet.
#
# 🚨Follow me and Retweet.
#
# #nft #nftart #nfts #art #crypto #nftartist #digitalart #nftcommunity #nftcollector #cryptoart #ethereum #cryptocurrency #opensea #blockchain #bitcoin #d #artist #nftcollectors #metaverse #ETH https://t.co/BKxvmC9vOB
# -------
# Tweet 13: Free #NFT Giveaway🎁
#
# 🚨Drop your $ETH address wallet.
#
# 🚨Follow me and Retweet.
# #nfts #nft #nftart #nftcommunity #nftcollector #nftartist #digitalart #crypto #cryptoart #art #ethereum #opensea #nftcollectors #blockchain #nftdrop #nftcollectibles #cryptocurrency #Bitcoin https://t.co/ZCFUoUQH1d
# Tweet 156: Free #NFT Giveaway🎁
#
# 🚨Drop your $ETH address wallet.
#
# 🚨Follow me and Retweet.
# #nfts #nft #nftart #nftcommunity #nftcollector #nftartist #digitalart #crypto #cryptoart #art #ethereum #opensea #nftcollectors #blockchain #nftdrop #nftcollectibles #cryptocurrency #Bitcoin https://t.co/b0yPj7cJCQ
# -------
# Tweet 13: Free #NFT Giveaway🎁
#
# 🚨Drop your $ETH address wallet.
#
# 🚨Follow me and Retweet.
# #nfts #nft #nftart #nftcommunity #nftcollector #nftartist #digitalart #crypto #cryptoart #art #ethereum #opensea #nftcollectors #blockchain #nftdrop #nftcollectibles #cryptocurrency #Bitcoin https://t.co/ZCFUoUQH1d
# Tweet 680: Free #NFT Giveaway🎁
#
# 🚨Drop your $ETH address wallet.
#
# 🚨Follow me and Retweet.
#
# #nft #nftart #nfts #art #crypto #nftartist #digitalart #nftcommunity #nftcollector #cryptoart #ethereum #cryptocurrency #opensea #blockchain #bitcoin #d #artist #nftcollectors #metaverse #ETH https://t.co/ebGOhhnFdJ
# -------
# Tweet 27: I did it for me. I liked it. I was good at it. And I was alive.
#
# #MONKEYS
# @elonmonkeys
#
# #SHIBAINU #shibarmy $SHIB $RINIA $QOM $CULT $SHI #SHIBKILLER $TSUKA $FLOKI $SANI $AKITA #SHYTOSHI #SHIBARIUM $ETH #BTC #CRYPTO #MEME #DOGE #BONE #LEASH #VOLT #WEB3 #DEFI #HOBBES #RINIA… https://t.co/1Gd1oIxKAD
# Tweet 57: I'm in the empire business
#
# @elonmonkeys #MONKEYS
#
# #SHIBAINU #shibarmy $SHIB $RINIA $QOM $CULT $SHI #SHIBKILLER $TSUKA $FLOKI $SANI $AKITA #SHYTOSHI #SHIBARIUM $ETH #BTC #CRYPTO #MEME #DOGE #BONE #LEASH #VOLT #WEB3 #DEFI #HOBBES #RINIA #GATSBY #DELREY #HAMLET https://t.co/AWAzNtwRlv
# -------
# Tweet 57: I'm in the empire business
#
# @elonmonkeys #MONKEYS
#
# #SHIBAINU #shibarmy $SHIB $RINIA $QOM $CULT $SHI #SHIBKILLER $TSUKA $FLOKI $SANI $AKITA #SHYTOSHI #SHIBARIUM $ETH #BTC #CRYPTO #MEME #DOGE #BONE #LEASH #VOLT #WEB3 #DEFI #HOBBES #RINIA #GATSBY #DELREY #HAMLET https://t.co/AWAzNtwRlv
# Tweet 138: I am buying more #MONKEYS
#
# Price is too juicy!
#
# #SHIBAINU #shibarmy $SHIB $RINIA $QOM $CULT $SHI #SHIBKILLER $TSUKA $FLOKI $SANI $AKITA #SHYTOSHI #SHIBARIUM $ETH #BTC #CRYPTO #MEME #DOGE #BONE #LEASH #VOLT #WEB3 #DEFI #HOBBES #RINIA #GATSBY #DELREY #HAMLET https://t.co/Zf5Dzvrptd
# -------
# Tweet 75: 🎁#Giveaways 🎁
#
# 🏆$15 #ETH
# 🏆Rekt Monkey #NFT
#
# 1⃣Follow me &amp;
# 2⃣RT &amp; Like❤️
# 3⃣Tag 2 friends
#
# ⏰24 hours
#
# #NFTs #Apt #SolNFT #EGLD #Solana #SOL #Binance    #BTC    #Aptos #PolygonNFT #cekilis #hamstercoin #NFTGiveaway #CNFT #ad https://t.co/4TzcJM0Hok
# Tweet 1276: 🎁#Giveaways 🎁
#
# 🏆$15 #ETH
# 🏆Rekt Monkey #NFT
#
# 1⃣Follow me &amp; @dianethereum 🔔
# 2⃣RT &amp; Like❤️
# 3⃣Tag 2 friends
#
# ⏰24 hours
#
# #NFTs #Apt #SolNFT #EGLD #Solana #SOL #Binance  #BTC  #Aptos #PolygonNFT #cekilis #hamstercoin #NFTGiveaway #CNFT #ad https://t.co/DbZOdd250L
# -------
# Tweet 88: Breaking : #LUNC to 1 USD: Terra Classic L1 Team Releases Q2 Roadmap
# #ustc #btc #usdt #binance
# Tweet 322: Breaking : #LUNC to 1 USD: Terra Classic L1 Team Releases Q2 Roadmap #Bullish
# #ustc #btc  #usdt  #binance  $lunc
# -------
# Tweet 110: IBIS SACRED, new solana project. metaverse community
# LINK : https://t.co/V0Otvt4e2D
#
# Be part of Ibis Sacred Community
#
# @hey_wallet
#   send 13333 $FRONK to the first 500 retweets and follows
#
# #Solana #bitcoin #FRONK #BONK #CRYPTO #ETH #BSC #BNB #metaverse https://t.co/uMTEryVKrN
# Tweet 111: We have deploy the alpha of our  2D metaverse on solana... Yes man
# LINK : https://t.co/V0Otvt4e2D
#
# Be part of Ibis Sacred Community
#
# @hey_wallet
#   send 13333 $FRONK to the first 500 retweets and follows
#
# #Solana #bitcoin #FRONK #BONK #CRYPTO #ETH #BSC #BNB #metaverse https://t.co/rqB418HhYN
# -------
# Tweet 117: Free #NFT Giveaway🎁
#
# 🚨Drop your $ETH address wallet.
#
# 🚨Follow me and Retweet.
#
# #nft #nftart #nfts #art #crypto #nftartist #digitalart #nftcommunity #nftcollector #cryptoart #ethereum #cryptocurrency #opensea #blockchain #bitcoin #d #artist #nftcollectors #metaverse #ETH https://t.co/BKxvmC9vOB
# Tweet 146: Free #NFT giveaway 🎁
#
# Drop your $ETH address
#
# Follow me&amp; RT
#
# #nft #nftart #nfts #art #crypto #nftartist #digitalart #nftcommunity #nftcollector #cryptoart #ethereum #cryptocurrency #opensea #blockchain #bitcoin #d #artist #nftcollectors #metaverse #eth #artwork #NFTdrops https://t.co/9ffwJuBjwg
# -------
# Tweet 117: Free #NFT Giveaway🎁
#
# 🚨Drop your $ETH address wallet.
#
# 🚨Follow me and Retweet.
#
# #nft #nftart #nfts #art #crypto #nftartist #digitalart #nftcommunity #nftcollector #cryptoart #ethereum #cryptocurrency #opensea #blockchain #bitcoin #d #artist #nftcollectors #metaverse #ETH https://t.co/BKxvmC9vOB
# Tweet 155: Free #NFT giveaway 👑 48 hours
# Drop your $ETH address
# Like + Follow me + Retweet
#
# #nft #nftart #nfts #art #crypto #nftartist #digitalart #nftcommunity #nftcollector #cryptoart #ethereum #cryptocurrency #opensea #blockchain #bitcoin #d #artist #nftcollectors #metaverse #ETH https://t.co/uTxU3glHbc
# -------
# Tweet 117: Free #NFT Giveaway🎁
#
# 🚨Drop your $ETH address wallet.
#
# 🚨Follow me and Retweet.
#
# #nft #nftart #nfts #art #crypto #nftartist #digitalart #nftcommunity #nftcollector #cryptoart #ethereum #cryptocurrency #opensea #blockchain #bitcoin #d #artist #nftcollectors #metaverse #ETH https://t.co/BKxvmC9vOB
# Tweet 156: Free #NFT Giveaway🎁
#
# 🚨Drop your $ETH address wallet.
#
# 🚨Follow me and Retweet.
# #nfts #nft #nftart #nftcommunity #nftcollector #nftartist #digitalart #crypto #cryptoart #art #ethereum #opensea #nftcollectors #blockchain #nftdrop #nftcollectibles #cryptocurrency #Bitcoin https://t.co/b0yPj7cJCQ
# -------
# Tweet 117: Free #NFT Giveaway🎁
#
# 🚨Drop your $ETH address wallet.
#
# 🚨Follow me and Retweet.
#
# #nft #nftart #nfts #art #crypto #nftartist #digitalart #nftcommunity #nftcollector #cryptoart #ethereum #cryptocurrency #opensea #blockchain #bitcoin #d #artist #nftcollectors #metaverse #ETH https://t.co/BKxvmC9vOB
# Tweet 680: Free #NFT Giveaway🎁
#
# 🚨Drop your $ETH address wallet.
#
# 🚨Follow me and Retweet.
#
# #nft #nftart #nfts #art #crypto #nftartist #digitalart #nftcommunity #nftcollector #cryptoart #ethereum #cryptocurrency #opensea #blockchain #bitcoin #d #artist #nftcollectors #metaverse #ETH https://t.co/ebGOhhnFdJ
# -------
# Tweet 117: Free #NFT Giveaway🎁
#
# 🚨Drop your $ETH address wallet.
#
# 🚨Follow me and Retweet.
#
# #nft #nftart #nfts #art #crypto #nftartist #digitalart #nftcommunity #nftcollector #cryptoart #ethereum #cryptocurrency #opensea #blockchain #bitcoin #d #artist #nftcollectors #metaverse #ETH https://t.co/BKxvmC9vOB
# Tweet 716: Free #NFT giveaway 🎁
#
# Drop your $ETH address
#
# Follow me&amp; RT
#
# #nft #nftart #nfts #art #crypto #nftartist #digitalart #nftcommunity #nftcollector #cryptoart #ethereum #cryptocurrency #opensea #blockchain #bitcoin #d #artist #nftcollectors #metaverse #eth #artwork #NFTdrops https://t.co/vvSFSWflvz
# -------
# Tweet 117: Free #NFT Giveaway🎁
#
# 🚨Drop your $ETH address wallet.
#
# 🚨Follow me and Retweet.
#
# #nft #nftart #nfts #art #crypto #nftartist #digitalart #nftcommunity #nftcollector #cryptoart #ethereum #cryptocurrency #opensea #blockchain #bitcoin #d #artist #nftcollectors #metaverse #ETH https://t.co/BKxvmC9vOB
# Tweet 732: Free #NFT giveaway 👑 48 hours
# Drop your $ETH address
# Like + Follow me + Retweet
#
# #nft #nftart #nfts #art #crypto #nftartist #digitalart #nftcommunity #nftcollector #cryptoart #ethereum #cryptocurrency #opensea #blockchain #bitcoin #d #artist #nftcollectors #metaverse #ETH https://t.co/G72Fap3E0N
# -------
# Tweet 146: Free #NFT giveaway 🎁
#
# Drop your $ETH address
#
# Follow me&amp; RT
#
# #nft #nftart #nfts #art #crypto #nftartist #digitalart #nftcommunity #nftcollector #cryptoart #ethereum #cryptocurrency #opensea #blockchain #bitcoin #d #artist #nftcollectors #metaverse #eth #artwork #NFTdrops https://t.co/9ffwJuBjwg
# Tweet 680: Free #NFT Giveaway🎁
#
# 🚨Drop your $ETH address wallet.
#
# 🚨Follow me and Retweet.
#
# #nft #nftart #nfts #art #crypto #nftartist #digitalart #nftcommunity #nftcollector #cryptoart #ethereum #cryptocurrency #opensea #blockchain #bitcoin #d #artist #nftcollectors #metaverse #ETH https://t.co/ebGOhhnFdJ
# -------
# Tweet 146: Free #NFT giveaway 🎁
#
# Drop your $ETH address
#
# Follow me&amp; RT
#
# #nft #nftart #nfts #art #crypto #nftartist #digitalart #nftcommunity #nftcollector #cryptoart #ethereum #cryptocurrency #opensea #blockchain #bitcoin #d #artist #nftcollectors #metaverse #eth #artwork #NFTdrops https://t.co/9ffwJuBjwg
# Tweet 716: Free #NFT giveaway 🎁
#
# Drop your $ETH address
#
# Follow me&amp; RT
#
# #nft #nftart #nfts #art #crypto #nftartist #digitalart #nftcommunity #nftcollector #cryptoart #ethereum #cryptocurrency #opensea #blockchain #bitcoin #d #artist #nftcollectors #metaverse #eth #artwork #NFTdrops https://t.co/vvSFSWflvz
# -------
# Tweet 149: GM #BTC by @BitcoinMagazine Schedule Fri 3/31 ☕️☀️
#
# #Bitcoin Media Roundtable  - 9am ET 🎙️
# @natbrunell
# @JoeNakamoto
#
# MMA, Freedom &amp; #BTC - 10am ET 🥊
# @Benaskren
# @mcshane_writes
#
# ⬇️ RSVP &amp; tune in ⬇️
# https://t.co/E5I8k6fO7e
# Tweet 881: GM #BTC by @BitcoinMagazine is LIVE! ☕️☀️
#
# #Bitcoin Media Roundtable  - 9am ET 🎙️
# @natbrunell
# @JoeNakamoto
#
# MMA, Freedom &amp; #BTC - 10am ET 🥊
# @Benaskren
# @mcshane_writes
#
# ⬇️ Join us! ⬇️
# https://t.co/E5I8k6fO7e
# -------
# Tweet 155: Free #NFT giveaway 👑 48 hours
# Drop your $ETH address
# Like + Follow me + Retweet
#
# #nft #nftart #nfts #art #crypto #nftartist #digitalart #nftcommunity #nftcollector #cryptoart #ethereum #cryptocurrency #opensea #blockchain #bitcoin #d #artist #nftcollectors #metaverse #ETH https://t.co/uTxU3glHbc
# Tweet 680: Free #NFT Giveaway🎁
#
# 🚨Drop your $ETH address wallet.
#
# 🚨Follow me and Retweet.
#
# #nft #nftart #nfts #art #crypto #nftartist #digitalart #nftcommunity #nftcollector #cryptoart #ethereum #cryptocurrency #opensea #blockchain #bitcoin #d #artist #nftcollectors #metaverse #ETH https://t.co/ebGOhhnFdJ
# -------
# Tweet 155: Free #NFT giveaway 👑 48 hours
# Drop your $ETH address
# Like + Follow me + Retweet
#
# #nft #nftart #nfts #art #crypto #nftartist #digitalart #nftcommunity #nftcollector #cryptoart #ethereum #cryptocurrency #opensea #blockchain #bitcoin #d #artist #nftcollectors #metaverse #ETH https://t.co/uTxU3glHbc
# Tweet 732: Free #NFT giveaway 👑 48 hours
# Drop your $ETH address
# Like + Follow me + Retweet
#
# #nft #nftart #nfts #art #crypto #nftartist #digitalart #nftcommunity #nftcollector #cryptoart #ethereum #cryptocurrency #opensea #blockchain #bitcoin #d #artist #nftcollectors #metaverse #ETH https://t.co/G72Fap3E0N
# -------
# Tweet 156: Free #NFT Giveaway🎁
#
# 🚨Drop your $ETH address wallet.
#
# 🚨Follow me and Retweet.
# #nfts #nft #nftart #nftcommunity #nftcollector #nftartist #digitalart #crypto #cryptoart #art #ethereum #opensea #nftcollectors #blockchain #nftdrop #nftcollectibles #cryptocurrency #Bitcoin https://t.co/b0yPj7cJCQ
# Tweet 680: Free #NFT Giveaway🎁
#
# 🚨Drop your $ETH address wallet.
#
# 🚨Follow me and Retweet.
#
# #nft #nftart #nfts #art #crypto #nftartist #digitalart #nftcommunity #nftcollector #cryptoart #ethereum #cryptocurrency #opensea #blockchain #bitcoin #d #artist #nftcollectors #metaverse #ETH https://t.co/ebGOhhnFdJ
# -------
# Tweet 211: 💧Hydro is now the leading source of power for #Bitcoin mining and is set to gain an even larger share in 2023 👀🙌 https://t.co/JU5JgL9tvs
# Tweet 427: 💧Hydro is now the leading source of power for #Bitcoin    mining and is set to gain an even larger share in 2023 👀🙌 https://t.co/D6vZmiE9d2
# -------
# Tweet 254: 🏴‍☠️#ARRR
#  #BTC #bitcoin #crypto #cryptocurrency
#
# ✅Pirate Chain is Private &amp; Anonymous
#
# 🚫Bitcoin is a transparent/traceable crypto
#
# Privacy is the future. *SHARE THIS VIDEO* https://t.co/jPpTMK9p4u
# Tweet 1365: 🏴‍☠️#ARRR
#  #BTC #bitcoin #crypto #cryptocurrency
#
# ✅Pirate Chain is Private &amp; Anonymous
#
# 🚫Bitcoin is a transparent/traceable crypto
#
# Privacy is the future. *SHARE THIS VIDEO* https://t.co/58VWlyG2Zy
# -------
# Tweet 423: 🏆 $LUNC is getting ready to climb the ranks of top cryptocurrencies.
#
# #lunc #crypto #luna #LunaClassic #LuncBurn #LuncArmy #LUNCcommunity #crypto #btc  #Binance https://t.co/MQlVV4XqQn
# Tweet 864: 🏆 $LUNC is getting ready to climb the ranks of top cryptocurrencies.
#
# #lunc #crypto #luna #LunaClassic #LuncBurn #LuncArmy #LUNCcommunity #crypto #btc   #Binance https://t.co/Z8CeTrJOIE
# -------
# Tweet 522: 🎁 #Gift &amp; #Giveaway 🎁
#
# 🏆0,60 $SOL/1 winner 🔥
#
# ⚔️Rules⚔️
# 1️⃣LIKE❤️- RT🔁
# 2️⃣Follow: @EmperorPromo
# 3️⃣Tag Friends
#
# ⏰48H
#
# #usdt    #bitcoin       #eth #Giveaway #NFTs #Airdrop #NFTCommunity #sol #avax       #egld #ada #matic #ftm #shiba #aptos #matic
# Tweet 1401: 🎁 #Gift &amp; #Giveaway 🎁
#
# 🏆0,25 $SOL/1 winner 🔥
#
# ⚔️Rules⚔️
# 1️⃣LIKE❤️- RT🔁
# 2️⃣Follow: @CryptoDrizzyy
# 3️⃣Tag Friends
#
# ⏰24H
#
# #usdt       #bitcoin          #eth #Giveaway #NFTs #Airdrop #NFTCommunity #sol #avax          #egld #ada #matic #ftm #shiba #aptos
# -------
# Tweet 554: I never used MoneyGram &amp; Western Union in my life.
#
# #Bitcoin fixes this.
# Tweet 933: I'd never used MoneyGram &amp; Western Union in my life.
#
# #Bitcoin fixes this.
# -------
# Tweet 579: ‼️🇺🇸 Space Force Major tells U.S. to stack #Bitcoin and develop domestic Bitcoin mining industry -  Politico
# Tweet 682: BREAKING NEWS: 🇺🇸 Space Force Major tells U.S. to stack #Bitcoin    and develop domestic Bitcoin mining industry -  Politico!
#
# Let's go #BTC 🌎🚀🚀
# -------
# Tweet 680: Free #NFT Giveaway🎁
#
# 🚨Drop your $ETH address wallet.
#
# 🚨Follow me and Retweet.
#
# #nft #nftart #nfts #art #crypto #nftartist #digitalart #nftcommunity #nftcollector #cryptoart #ethereum #cryptocurrency #opensea #blockchain #bitcoin #d #artist #nftcollectors #metaverse #ETH https://t.co/ebGOhhnFdJ
# Tweet 716: Free #NFT giveaway 🎁
#
# Drop your $ETH address
#
# Follow me&amp; RT
#
# #nft #nftart #nfts #art #crypto #nftartist #digitalart #nftcommunity #nftcollector #cryptoart #ethereum #cryptocurrency #opensea #blockchain #bitcoin #d #artist #nftcollectors #metaverse #eth #artwork #NFTdrops https://t.co/vvSFSWflvz
# -------
# Tweet 680: Free #NFT Giveaway🎁
#
# 🚨Drop your $ETH address wallet.
#
# 🚨Follow me and Retweet.
#
# #nft #nftart #nfts #art #crypto #nftartist #digitalart #nftcommunity #nftcollector #cryptoart #ethereum #cryptocurrency #opensea #blockchain #bitcoin #d #artist #nftcollectors #metaverse #ETH https://t.co/ebGOhhnFdJ
# Tweet 732: Free #NFT giveaway 👑 48 hours
# Drop your $ETH address
# Like + Follow me + Retweet
#
# #nft #nftart #nfts #art #crypto #nftartist #digitalart #nftcommunity #nftcollector #cryptoart #ethereum #cryptocurrency #opensea #blockchain #bitcoin #d #artist #nftcollectors #metaverse #ETH https://t.co/G72Fap3E0N
# -------
# Tweet 703: JUST IN: Germany's 2nd largest stock exchange approved to offer #Bitcoin and crypto custody 🇩🇪 https://t.co/bE5raSSnj4
# Tweet 929: Crypto News: 🇩🇪 Germany's 2nd largest stock exchange approved to offer #Bitcoin  and #crypto custody
# -------
# Tweet 710: #PawSwap plans to integrate the following chains, aside from #ETH and #BNB, considers #Bitcoin too. @Dezaxe $PAW https://t.co/NGgpolcEM6
# Tweet 733: #PawSwap plans to integrate the following chains, aside from #ETH and #BNB, considers #Bitcoin too. @Dezaxe $PAW https://t.co/H0DA0n3JsO
# -------
# Tweet 807: 🚀#BICONOMYEXCHANGE MARKET STATS 🚀
#
# 🚀TOP GAINERS IN #BICONOMY 🏆
#
# $BABYDOGE @BabyDogeCoin
# $BLUR @blur_io
# $VINU @VitaInuCoin
# $STRM @streamcoin_strm
# $OP @optimismFND
#
# ✅JOIN US: https://t.co/r4JBysetIs
#
# #Crypto #Trading #Bitcoin #BTC #ETH #BIT #Cryptocurrencies #altcoins https://t.co/BPRxlg4WzY
# Tweet 855: 🚀#BICONOMYEXCHANGE MARKET STATS 🚀
#
# 🚀TOP GAINERS IN #BICONOMY 🏆
#
# $BABYDOGE
# @BabyDogeCoin
#
# $BLUR
# @blur_io
#
# $VINU
# @VitaInuCoin
#
# $STRM
# @streamcoin_strm
#
# $OP
# @optimismFND
#
# #Crypto #Trading #Bitcoin #BTC #ETH #BIT #Cryptocurrencies #altcoins https://t.co/gq4iAsYYfL
# -------
# Tweet 843: WSJ: The banking turmoil has "boosted confidence" of #Bitcoin as an alternative to traditional banking 🚀
# Tweet 851: BREAKING🚨: @WSJ: The banking turmoil has "boosted confidence" of #Bitcoin as a new alternative to traditional banking. 📈
# -------
# Tweet 884: $BKKT $CORZQ WILL BE BIGGEST GAINERS FROM #Bitcoin  RISE AND ADOPTION
#
# THE MORE #BTC  PRICE GOES UP, $CORZQ PROFITS GO UP 🚀
#
# $BKKT $CORZQ #StocksInFocus Linked to #Bitcoin  #BTC  #Crypto #cryptocurrency
#
# Bitcoin price briefly hits $29K  https://t.co/nKvFzYKMeE
# Tweet 930: $BKKT $CORZQ COULD BE BIGGEST GAINERS FROM #Bitcoin RISE AND ADOPTION
#
# THE MORE #BTC PRICE GOES UP, $BKKT $CORZQ PROFITS GO UP 🚀
#
# $BKKT $CORZQ #StocksInFocus Linked to #Bitcoin #BTC #Crypto #cryptocurrency
#
# Bitcoin Price Can Hit $35k In Coming Week… https://t.co/ASkGQjDPve
# -------
# Tweet 916: Cardano Wallets To Access Ethereum Dapps Thanks to This Move
#
# #Cardano #cardanofeed #ADA #crypto #cardanocommunity #bitcoin #CoinMarketCap #blockchain #cryptocurrency #CardanoADA #btc $ADA
# https://t.co/eonP9OXrkT
# Tweet 956: Cardano Users Can Soon Access Ethereum dApps Directly From ADA Wallets
#
# #Cardano #cardanofeed #ADA #crypto #cardanocommunity #bitcoin #CoinMarketCap #blockchain #cryptocurrency #CardanoADA #btc $ADA
# https://t.co/1Y98Q9gxSB
# -------
# Tweet 930: $BKKT $CORZQ COULD BE BIGGEST GAINERS FROM #Bitcoin RISE AND ADOPTION
#
# THE MORE #BTC PRICE GOES UP, $BKKT $CORZQ PROFITS GO UP 🚀
#
# $BKKT $CORZQ #StocksInFocus Linked to #Bitcoin #BTC #Crypto #cryptocurrency
#
# Bitcoin Price Can Hit $35k In Coming Week… https://t.co/ASkGQjDPve
# Tweet 945: $BKKT $CORZQ COULD BE BIGGEST GAINERS FROM #Bitcoin RISE AND ADOPTION
#
# THE MORE #BTC PRICE GOES UP, $BKKT $CORZQ PROFITS GO UP 🚀
#
# $BKKT $CORZQ #StocksInFocus Linked to #Bitcoin #BTC #Crypto #cryptocurrency
#
# Pentagon, Mine Bitcoin To Stay Superpower… https://t.co/lNWE0dM4HP
# -------
# Tweet 930: $BKKT $CORZQ COULD BE BIGGEST GAINERS FROM #Bitcoin RISE AND ADOPTION
#
# THE MORE #BTC PRICE GOES UP, $BKKT $CORZQ PROFITS GO UP 🚀
#
# $BKKT $CORZQ #StocksInFocus Linked to #Bitcoin #BTC #Crypto #cryptocurrency
#
# Bitcoin Price Can Hit $35k In Coming Week… https://t.co/ASkGQjDPve
# Tweet 1005: $BKKT $CORZQ COULD BE BIGGEST GAINERS FROM #Bitcoin RISE AND ADOPTION
#
# THE MORE #BTC  PRICE GOES UP, $BKKT $CORZQ PROFITS GO UP 🚀
#
# $BKKT $CORZQ #StocksInFocus Linked to #Bitcoin #BTC #Crypto #cryptocurrency
#
# Bitcoin Steadies After Inflation Data… https://t.co/0jmuC584oV
# -------
# Tweet 945: $BKKT $CORZQ COULD BE BIGGEST GAINERS FROM #Bitcoin RISE AND ADOPTION
#
# THE MORE #BTC PRICE GOES UP, $BKKT $CORZQ PROFITS GO UP 🚀
#
# $BKKT $CORZQ #StocksInFocus Linked to #Bitcoin #BTC #Crypto #cryptocurrency
#
# Pentagon, Mine Bitcoin To Stay Superpower… https://t.co/lNWE0dM4HP
# Tweet 1005: $BKKT $CORZQ COULD BE BIGGEST GAINERS FROM #Bitcoin RISE AND ADOPTION
#
# THE MORE #BTC  PRICE GOES UP, $BKKT $CORZQ PROFITS GO UP 🚀
#
# $BKKT $CORZQ #StocksInFocus Linked to #Bitcoin #BTC #Crypto #cryptocurrency
#
# Bitcoin Steadies After Inflation Data… https://t.co/0jmuC584oV
# -------
# Tweet 1051: COMING SOON!!!! @BitApes_btc @MagicEden #Bitcoin #BitApes #Ordinal #NFT #MagicEden https://t.co/5hyXp8hVLF
# Tweet 1130: COMING SOON!!!! @BitApes_btc @MagicEden #Bitcoin  #BitApes #Ordinal #NFT #MagicEden https://t.co/zHSgo4Ojl2
# -------
# Tweet 1052: #Bitcoin IS READY FOR A MASSIVE BULL RUN
# @AurelienOhayon
#
# $BKKT $CORZQ BULL RUN BEGINS, COULD BE BIGGEST GAINERS FROM #Bitcoin RISE AND ADOPTION
#
# $BKKT $CORZQ
# #StocksInFocus Linked to #Bitcoin  #BTC  #Crypto #cryptocurrency https://t.co/fGB14SFjqJ
# Tweet 1057: #Bitcoin 2023 Bull Run Begins‼️💯🙏
#
# $BKKT $CORZQ BULL RUN BEGINS, COULD BE BIGGEST GAINERS FROM #Bitcoin  RISE AND ADOPTION
#
# $BKKT $CORZQ
# #StocksInFocus Linked to #Bitcoin   #BTC   #Crypto #cryptocurrency https://t.co/YhrEPcjHZW
# -------
# Tweet 1057: #Bitcoin 2023 Bull Run Begins‼️💯🙏
#
# $BKKT $CORZQ BULL RUN BEGINS, COULD BE BIGGEST GAINERS FROM #Bitcoin  RISE AND ADOPTION
#
# $BKKT $CORZQ
# #StocksInFocus Linked to #Bitcoin   #BTC   #Crypto #cryptocurrency https://t.co/YhrEPcjHZW
# Tweet 1066: I BELIEVE #Bitcoin #Crypto WILL BE OUR FUTURE‼️
#
# $BKKT $CORZQ BULL RUN BEGINS, COULD BE BIGGEST GAINERS FROM #Bitcoin RISE AND ADOPTION
#
# $BKKT $CORZQ
# #StocksInFocus Linked to #Bitcoin   #BTC   #Crypto #cryptocurrency https://t.co/rZvVVIL25M
# -------
# Tweet 1149: $LUNC happy Friday y'all! Bring on some weekend pumps 🤑
#
# $lunc #lunc #crypto #luna #LunaClassic #LuncBurn #LuncArmy #LUNCcommunity #crypto #btc   #Binance https://t.co/epdmWA837V
# Tweet 1168: $LUNC happy Friday y'all! Bring on some weekend pumps 🤑
#
# $lunc #lunc #crypto #luna #LunaClassic #LuncBurn #LuncArmy #LUNCcommunity #crypto #btc #Binance https://t.co/5GlYEvknWM
# -------
# Tweet 1175: JUST IN: 🇺🇸 US government sold 9,800 #Bitcoin and intends to sell 41,500 more #BTC connected to Silk Road.
# Tweet 1179: 🚨🚨 US government sold 9,800 #Bitcoin  and intends to sell 41,500 more #BTC  connected to Silk Road.
# -------
# Tweet 1175: JUST IN: 🇺🇸 US government sold 9,800 #Bitcoin and intends to sell 41,500 more #BTC connected to Silk Road.
# Tweet 1186: JUST IN: 🇺🇸 US government sold 9,800 #Bitcoin    and intends to sell 41,500 more #BTC    connected to Silk Road. https://t.co/6GYDqSqqej
# -------
# Tweet 1179: 🚨🚨 US government sold 9,800 #Bitcoin  and intends to sell 41,500 more #BTC  connected to Silk Road.
# Tweet 1186: JUST IN: 🇺🇸 US government sold 9,800 #Bitcoin    and intends to sell 41,500 more #BTC    connected to Silk Road. https://t.co/6GYDqSqqej
# -------
# Tweet 1180: JUST IN: 🇺🇸 US government to sell 41,500 #Bitcoin ($1.18 billion) connected to Silk Road, in four batches this year.
# Tweet 1206: 🚨#BREAKING: US government to sell 41,500 #Bitcoin  ($1.18 billion) connected to Silk Road, in four batches this year.
# -------
# Tweet 1237: JUST IN: 🇺🇲 US government has sold 9,800 #Bitcoin and plans to sell an additional 41,500 BTC related to Silk Road.
# Tweet 1260: 🚨US government has sold 9,800 #Bitcoin and plans to sell an additional 41,500 BTC related to Silk Road. https://t.co/eW8OceHf1V
# -------
# Tweet 1369: Biggest Movers: Cardano Moves to 6-Week High, Climbing by Over 6% on Friday – Market Updates Bitcoin News
#
# #Cardano #cardanofeed #ADA #crypto #cardanocommunity #bitcoin #CoinMarketCap #blockchain #cryptocurrency #CardanoADA #btc $ADA
# https://t.co/qQI1gl8I4K
# Tweet 1432: Biggest Movers: Cardano Moves to 6-Week High, Climbing by Over 6% on Friday | Crypto Breaking News
#
# #Cardano #cardanofeed #ADA #crypto #cardanocommunity #bitcoin #CoinMarketCap #blockchain #cryptocurrency #CardanoADA #btc $ADA
# https://t.co/wTwZSPH88F
# -------

# %% [markdown]
# Skip the code in the above cell. Below is the same code as a function and will furter go in class.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def remove_similar_content(df, content_column, similarity_threshold=0.8):
    """
    Removes samples with similar content from a DataFrame based on cosine similarity.

    Parameters:
    - df: pd.DataFrame
        The DataFrame containing the dataset.
    - content_column: str
        The name of the column containing the text content to analyze.
    - similarity_threshold: float (default=0.8)
        The threshold for cosine similarity above which samples are considered similar.

    Returns:
    - pd.DataFrame
        The DataFrame with similar content removed.
    """
    # Vectorize the content column
    tfidf = TfidfVectorizer(stop_words='english')
    tfidf_matrix = tfidf.fit_transform(df[content_column])

    # Calculate cosine similarity matrix
    cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

    # Set to keep track of indices to remove
    indices_to_remove = set()

    # Loop through the similarity matrix to find similar content
    for i in range(len(cosine_sim)):
        for j in range(i + 1, len(cosine_sim)):
            if cosine_sim[i, j] > similarity_threshold:
                # Mark both indices for removal
                indices_to_remove.add(i)
                indices_to_remove.add(j)

    # Create a new DataFrame excluding the indices found to be similar
    df_cleaned = df.drop(index=indices_to_remove).reset_index(drop=True)

    return df_cleaned

# Example usage:
# Assuming your data is in a DataFrame called `df` with a 'content' column
# df_cleaned = remove_similar_content(df, content_column='content')

# %%
df = remove_similar_content(df, 'content', 0.65)

# %%
df.shape
# Out:
# (1408, 6)

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# True     1134
# False     274
# Name: count, dtype: int64

# %% [markdown]
# ### 4. Repetitive Phrases (N-gram Analysis)

# %% [markdown]
# Detect n-grams that are overly common in tweets.

# %%
from collections import Counter
from nltk import ngrams
import nltk

# Make sure to download necessary NLTK data
# nltk.download('punkt')

# Function to get n-grams
def get_ngrams(text, n=3):
    words = nltk.word_tokenize(text)
    return list(ngrams(words, n))

# Apply n-gram extraction
df['ngrams'] = df['content'].apply(lambda x: get_ngrams(x, n=5))

# Flatten the list of n-grams and count frequencies
ngram_list = [ngram for sublist in df['ngrams'] for ngram in sublist]
ngram_freq = Counter(ngram_list)

# Find common n-grams (e.g., those that appear more than 5 times)
common_ngrams = {ngram: count for ngram, count in ngram_freq.items() if count > 5}
print(common_ngrams)

# %% [markdown]
# The methods for detecting and removing bot tweets should generally be applied **before** text processing (like removing stop words, lemmatization, punctuation removal, etc.). Here's why:
#
# ### 1. **Bot Detection Is More Reliable on Raw Text**
#    - **Username and Content Similarity:** Bots often generate content that is templated or repetitive. If you process the text (e.g., removing stopwords or punctuation) before running similarity checks, you might lose some of the patterns that are indicative of bot activity. For example, removing punctuation could change the structure of the text, making similar bot-generated content appear more diverse than it actually is.
#    - **N-gram Analysis:** If you preprocess the text before generating n-grams, you might alter the n-grams in a way that makes them less effective for detecting repetitive phrases. For example, lemmatization could merge different forms of a word, potentially masking the repetitive nature of bot-generated text.
#
# ### 2. **Cleaner Data for Sentiment Analysis**
#    - **After Bot Removal:** Once you've identified and removed potential bot tweets, you can then proceed with text processing like stop word removal, lemmatization, and punctuation removal. This ensures that the remaining text is cleaned and ready for more accurate sentiment analysis.
#
# ### Workflow Suggestion:
#
# 1. **Raw Data:**
#    - **Bot Detection:** Apply the username analysis, content similarity analysis, and possibly n-gram analysis on the raw text to flag and remove suspicious tweets.
#
# 2. **Text Processing:**
#    - **Cleaning:** After bot removal, proceed with standard text processing steps such as:
#      - Lowercasing
#      - Removing stop words
#      - Lemmatization or stemming
#      - Removing punctuation
#      - Tokenization
#
# 3. **Sentiment Analysis:**
#    - **Model Training:** Use the cleaned dataset, now with reduced noise from potential bot-generated content, to train your sentiment analysis model.
#
# By following this approach, you ensure that bot detection is based on the full, unaltered text, making it more effective. After bot removal, your sentiment analysis can proceed with clean, human-generated content, leading to more reliable results.
